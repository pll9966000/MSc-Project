# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
final_data = pd.read_csv('final_data.csv')

# %%
Renal_Failure_data=final_data.drop(['Unnamed: 0'], axis=1)

# %%
#The individual values in the string column are represented by numbers.
Renal_Failure_data['GENDER']=Renal_Failure_data['GENDER'].map({'M':1,'F':2}).astype(int)
Renal_Failure_data['MARITAL_STATUS']=Renal_Failure_data['MARITAL_STATUS'].map({'DIVORCED':1,'LIFE PARTNER':2,'MARRIED':3,'SEPARATED':4,'SINGLE':5,'WIDOWED':6}).astype(int)
Renal_Failure_data['ETHNICITY']=Renal_Failure_data['ETHNICITY'].map({'ASIAN':1,'BLACK':2,'HISPANIC':3,'WHITE':4}).astype(int)
Renal_Failure_data
# Out:
#       PATIENT_ID  AGE  GENDER  MARITAL_STATUS  ETHNICITY  Blood_Calcium  \
# 0              0   49       2               5          4       0.131579
# 1              1   23       2               5          2       0.625000
# 2              2   76       2               3          4       0.222222
# 3              3   69       2               3          4       0.500000
# 4              4   58       2               6          4       0.857143
# ...          ...  ...     ...             ...        ...            ...
# 5919        5919   72       1               3          4       0.357143
# 5920        5920   78       1               3          4       0.142857
# 5921        5921   74       2               3          1       0.500000
# 5922        5922   60       1               5          2       0.428571
# 5923        5923   87       2               6          4       0.166667
#
#       Blood_Creatinine  Blood_Glucose  Blood_pH  Blood_Urea_Nitrogen  \
# ...

# %%
#Check the table for null values
Renal_Failure_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5924 entries, 0 to 5923
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PATIENT_ID           5924 non-null   int64
#  1   AGE                  5924 non-null   int64
#  2   GENDER               5924 non-null   int64
#  3   MARITAL_STATUS       5924 non-null   int64
#  4   ETHNICITY            5924 non-null   int64
#  5   Blood_Calcium        5924 non-null   float64
#  6   Blood_Creatinine     5914 non-null   float64
#  7   Blood_Glucose        5912 non-null   float64
#  8   Blood_pH             3717 non-null   float64
#  9   Blood_Urea_Nitrogen  5914 non-null   float64
#  10  Urine                5615 non-null   float64
#  11  diabetes             5924 non-null   int64
#  12  hypertension         5924 non-null   int64
#  13  Death_Flag           5924 non-null   int64
# dtypes: float64(6), int64(8)
# memory usage: 648.1 KB

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

pipeline = Pipeline([
    # Deal with the NaN value
    ('imputer',SimpleImputer(strategy="median"))
])

# %%
features_prepared = pipeline.fit_transform(Renal_Failure_data)

# %%
final_data_1=pd.DataFrame(features_prepared)
final_data_1
# Out:
#           0     1    2    3    4         5         6         7         8   \
# 0        0.0  49.0  2.0  5.0  4.0  0.131579  0.613636  0.807692  0.379310
# 1        1.0  23.0  2.0  5.0  2.0  0.625000  0.000000  0.495652  0.190476
# 2        2.0  76.0  2.0  3.0  4.0  0.222222  0.965517  0.833333  0.200000
# 3        3.0  69.0  2.0  3.0  4.0  0.500000  0.666667  0.333333  0.875000
# 4        4.0  58.0  2.0  6.0  4.0  0.857143  0.666667  0.888889  0.294118
# ...      ...   ...  ...  ...  ...       ...       ...       ...       ...
# 5919  5919.0  72.0  1.0  3.0  4.0  0.357143  0.705882  0.882353  0.294118
# 5920  5920.0  78.0  1.0  3.0  4.0  0.142857  0.875000  0.875000  0.294118
# 5921  5921.0  74.0  2.0  3.0  1.0  0.500000  0.117647  0.823529  0.333333
# 5922  5922.0  60.0  1.0  5.0  2.0  0.428571  0.142857  0.285714  0.294118
# 5923  5923.0  87.0  2.0  6.0  4.0  0.166667  0.148148  0.744681  0.285714
#
#             9         10   11   12   13
# ...

# %%
final_data_1.columns=[Renal_Failure_data.columns.values]
final_data_1
# Out:
#      PATIENT_ID   AGE GENDER MARITAL_STATUS ETHNICITY Blood_Calcium  \
# 0           0.0  49.0    2.0            5.0       4.0      0.131579
# 1           1.0  23.0    2.0            5.0       2.0      0.625000
# 2           2.0  76.0    2.0            3.0       4.0      0.222222
# 3           3.0  69.0    2.0            3.0       4.0      0.500000
# 4           4.0  58.0    2.0            6.0       4.0      0.857143
# ...         ...   ...    ...            ...       ...           ...
# 5919     5919.0  72.0    1.0            3.0       4.0      0.357143
# 5920     5920.0  78.0    1.0            3.0       4.0      0.142857
# 5921     5921.0  74.0    2.0            3.0       1.0      0.500000
# 5922     5922.0  60.0    1.0            5.0       2.0      0.428571
# 5923     5923.0  87.0    2.0            6.0       4.0      0.166667
#
#      Blood_Creatinine Blood_Glucose  Blood_pH Blood_Urea_Nitrogen     Urine  \
# ...

# %%
final_data_1[['PATIENT_ID']] = final_data_1[['PATIENT_ID']].astype(int)
final_data_1[['AGE']] = final_data_1[['AGE']].astype(int)
final_data_1[['GENDER']] = final_data_1[['GENDER']].astype(int)
final_data_1[['MARITAL_STATUS']] = final_data_1[['MARITAL_STATUS']].astype(int)
final_data_1[['ETHNICITY']] = final_data_1[['ETHNICITY']].astype(int)
final_data_1[['diabetes']] = final_data_1[['diabetes']].astype(int)
final_data_1[['hypertension']] = final_data_1[['hypertension']].astype(int)
final_data_1[['Death_Flag']] = final_data_1[['Death_Flag']].astype(int)
final_data_1
# Out:
#      PATIENT_ID AGE GENDER MARITAL_STATUS ETHNICITY Blood_Calcium  \
# 0             0  49      2              5         4      0.131579
# 1             1  23      2              5         2      0.625000
# 2             2  76      2              3         4      0.222222
# 3             3  69      2              3         4      0.500000
# 4             4  58      2              6         4      0.857143
# ...         ...  ..    ...            ...       ...           ...
# 5919       5919  72      1              3         4      0.357143
# 5920       5920  78      1              3         4      0.142857
# 5921       5921  74      2              3         1      0.500000
# 5922       5922  60      1              5         2      0.428571
# 5923       5923  87      2              6         4      0.166667
#
#      Blood_Creatinine Blood_Glucose  Blood_pH Blood_Urea_Nitrogen     Urine  \
# 0            0.613636      0.807692  0.379310            0.954545  0.031746
# ...

# %%
#Observe the balance of data
final_data_1.Death_Flag.value_counts()
# Out:
# (Death_Flag,)
# 0                4886
# 1                1038
# dtype: int64

# %%
corrRF = final_data_1.corr()
corrRF
# Out:
#                     PATIENT_ID       AGE    GENDER MARITAL_STATUS ETHNICITY  \
# PATIENT_ID            1.000000 -0.046505 -0.020489       0.014584 -0.044368
# AGE                  -0.046505  1.000000  0.054233       0.050567  0.098457
# GENDER               -0.020489  0.054233  1.000000       0.177267 -0.067588
# MARITAL_STATUS        0.014584  0.050567  0.177267       1.000000 -0.072431
# ETHNICITY            -0.044368  0.098457 -0.067588      -0.072431  1.000000
# Blood_Calcium        -0.069630 -0.018013 -0.040400      -0.025401  0.074422
# Blood_Creatinine     -0.136426  0.115092 -0.137075      -0.033334 -0.040664
# Blood_Glucose        -0.025328  0.078542 -0.058467      -0.033745  0.008401
# Blood_pH             -0.172315 -0.013202  0.040831      -0.014772 -0.023908
# Blood_Urea_Nitrogen  -0.161537  0.290250 -0.072253      -0.020987  0.064267
# Urine                 0.160212  0.046861  0.036888      -0.007321 -0.012766
# ...

# %%
final_data_1.to_csv('processed_data2.csv')
